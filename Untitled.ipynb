# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# EDA

# %%
#read data
data = pd.read_csv('data.csv', encoding="ISO-8859-1")
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
#checking for outliers
data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
data.describe(include='object')
# Out:
#        InvoiceNo StockCode                         Description  \
# count     541909    541909                              540455
# unique     25900      4070                                4223
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq        1114      2313                                2369
#
#              InvoiceDate         Country
# count             541909          541909
# unique             23260              38
# top     10/31/2011 14:41  United Kingdom
# freq                1114          495478

# %%
data = data.drop('CustomerID', axis=1)

# %%
f = plt.figure(figsize=(20,10))
sns.countplot(data.Country);
data.Country.value_counts()
# Out:
# UK                      495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
data.loc[data.Country=='United Kingdom', 'Country'] = 'UK'
data.loc[data.Country!='UK', 'Country'] = 'Not UK'

# %%
data.Country.value_counts()
# Out:
# UK        495478
# Not UK     46431
# Name: Country, dtype: int64

# %%
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

# %%
data['year'] = pd.DatetimeIndex(data['InvoiceDate']).year
data['month'] = pd.DatetimeIndex(data['InvoiceDate']).month
data['dayofweek'] = pd.DatetimeIndex(data['InvoiceDate']).dayofweek
data['weekofyear'] = pd.DatetimeIndex(data['InvoiceDate']).weekofyear

# %%
data_full = data.copy()
data = data.drop(columns=['Description', 'InvoiceDate'])

# %%
data
# Out:
#        InvoiceNo StockCode  Quantity  UnitPrice Country  year  month  \
# 0         536365    85123A         6       2.55      UK  2010     12
# 1         536365     71053         6       3.39      UK  2010     12
# 2         536365    84406B         8       2.75      UK  2010     12
# 3         536365    84029G         6       3.39      UK  2010     12
# 4         536365    84029E         6       3.39      UK  2010     12
# ...          ...       ...       ...        ...     ...   ...    ...
# 541904    581587     22613        12       0.85  Not UK  2011     12
# 541905    581587     22899         6       2.10  Not UK  2011     12
# 541906    581587     23254         4       4.15  Not UK  2011     12
# 541907    581587     23255         4       4.15  Not UK  2011     12
# 541908    581587     22138         3       4.95  Not UK  2011     12
#
#         dayofweek  weekofyear
# 0               2          48
# 1               2          48
# 2               2          48
# ...
